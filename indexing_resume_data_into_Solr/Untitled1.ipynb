# %%
print('hi')
# Out:
# hi

# %%
folder = '/home/sanjay_kumar/Downloads/Resumes'

# %%
import os 
lst = []

# %%
for file in os.listdir(folder):
    if file.endswith('.pdf'):
        filepath = os.path.join(folder,file)
        filesize = os.path.getsize(filepath)/(1024*1024)
        filetype = 'pdf'
    lst.append([file,round(filesize,2),filetype])

# %%
print(lst)
# Out:
# [['SANJAY KUMAR S Resume.pdf', 0.28, 'pdf'], ['Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf', 0.81, 'pdf'], ['web-developer-resume-example.pdf', 0.04, 'pdf'], ['Naukri_KirubaJ[4y_0m] 1.pdf', 1.23, 'pdf'], ['Naukri_KarthickrajaEM[3y_0m] 1.pdf', 0.82, 'pdf'], ['Naukri_NishanaPradeep[2y_0m] 1.pdf', 0.54, 'pdf'], ['radhakrishnan.pdf', 0.06, 'pdf'], ['Resume_AI Team.pdf', 0.31, 'pdf'], ['Naukri_RadhakrishnanM[3y_0m] 1.pdf', 0.06, 'pdf']]

# %%
df = pd.DataFrame(lst)

# %%
df.head()
# Out:
#                                          0     1    2
# 0                SANJAY KUMAR S Resume.pdf  0.28  pdf
# 1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf  0.81  pdf
# 2         web-developer-resume-example.pdf  0.04  pdf
# 3              Naukri_KirubaJ[4y_0m] 1.pdf  1.23  pdf
# 4       Naukri_KarthickrajaEM[3y_0m] 1.pdf  0.82  pdf

# %%
df.rename(columns={0: 'File_Name', 1: 'Filesize_in_mb', 2: 'File_Type'}, inplace=True)

# %%
df.head()
# Out:
#                                  File_Name  Filesize_in_mb File_Type
# 0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 2         web-developer-resume-example.pdf            0.04       pdf
# 3              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 4       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf

# %%
df['File_Name']
# Out:
# 0                  SANJAY KUMAR S Resume.pdf
# 1    Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf
# 2           web-developer-resume-example.pdf
# 3                Naukri_KirubaJ[4y_0m] 1.pdf
# 4         Naukri_KarthickrajaEM[3y_0m] 1.pdf
# 5         Naukri_NishanaPradeep[2y_0m] 1.pdf
# 6                          radhakrishnan.pdf
# 7                         Resume_AI Team.pdf
# 8         Naukri_RadhakrishnanM[3y_0m] 1.pdf
# Name: File_Name, dtype: object

# %%
lst2 = df['File_Name'].tolist()

# %%
lst2
# Out:
# ['SANJAY KUMAR S Resume.pdf',
#  'Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf',
#  'web-developer-resume-example.pdf',
#  'Naukri_KirubaJ[4y_0m] 1.pdf',
#  'Naukri_KarthickrajaEM[3y_0m] 1.pdf',
#  'Naukri_NishanaPradeep[2y_0m] 1.pdf',
#  'radhakrishnan.pdf',
#  'Resume_AI Team.pdf',
#  'Naukri_RadhakrishnanM[3y_0m] 1.pdf']

# %%
resume_text=[]

# %%
# !pip install pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pdfplumber

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:  
            text += page.extract_text() + '\n' 
    cleaned_text = text.replace('\n', ' ').replace('  ', ' ') 
    cleaned_text = ' '.join(cleaned_text.split()) 

    return cleaned_text
    

for file in df['File_Name'].tolist() :
    text = extract_text_from_pdf((folder+'/'+file))
    resume_text.append(text)

# %%
resume_text.clear()

# %%
resume_text
# Out:
# ['SANJAY KUMAR S Phone: +91 7094583155 | Email: sanjaykumarcsk2002@gmail.com | Linked In: SanjayKumar03 EDUCATION Sri Eshwar College of Engineering B.E (CSE) 9.1(CGPA) 2019-2023 Vivek Vidyalaya Matric Higher Secondary School HSC 93% 2017-2019 Vivek Vidyalaya Matric Higher Secondary School SSLC 98% 2016-2017 INTERNSHIPS Etl Development – Virtusa Corporation Supported data integration initiatives by performing ETL (Extract, Transform, Load) operations across diverse data sources, including relational databases (MySQL) and flat files (CSV). Applied data quality assessment techniques to enhance data integrity. Leveraged Java for customizations within Talend for improved ETL workflows. Engaged in team meetings, code reviews, and project discussions to ensure alignment and resolve technical challenges related to data integration. Tech Stack -- Talend Open Studio (TOS), Talend Administration Centre (TAC), MySQL, Java. Data Science with Python– Gateway Solutions Gained hands-on experience in
# ...

# %%
df.head()
# Out:
#                                  File_Name  Filesize_in_mb File_Type
# 0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 2         web-developer-resume-example.pdf            0.04       pdf
# 3              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 4       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf

# %%
df['File_text'] = resume_text

# %%
df.head(10)
# Out:
#                                  File_Name  Filesize_in_mb File_Type  \
# 0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 2         web-developer-resume-example.pdf            0.04       pdf
# 3              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 4       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf
# 5       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54       pdf
# 6                        radhakrishnan.pdf            0.06       pdf
# 7                       Resume_AI Team.pdf            0.31       pdf
# 8       Naukri_RadhakrishnanM[3y_0m] 1.pdf            0.06       pdf
#
#                                            File_text
# 0  SANJAY KUMAR S Phone: +91 7094583155 | Email: ...
# 1  Vijaykumar SD Contact: +91 9566859696 E-Mail: ...
# 2  JACKSON CAREER OBJECTIVE Software engineer wit...
# 3  Kiruba J UI & UX Designer and Product designer...
# ...

# %%
json_data = []

# %%
import json
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
import time

# %%
def generate_fields_from_resume(resume_text):
    llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro", google_api_key="AIzaSyC_RmTwAAoVxr-U1sHpxHD0axK34lLDxRk")
    prompt_template = PromptTemplate.from_template(
        """Extract the following fields from the resume text 
1. first_name
2. last_name
3. emails
4. phones
5. skills
6. highest_degree_details
7. pg_degree
8. ug_degree
9. ug_graduation_year
10. first_working_date
11. state
12. city
13. company_history (Don't include internships and courses)
14. marital_status
15. gender
16. skill_bucket
17. domain_experience

Resume Text:
{resume_text}

Provide the details only in JSON datatype, with no extra lines or text or words so that the output can be converted into a proper json type
"""
    )

    chain = LLMChain(llm=llm, prompt=prompt_template)
    response = chain.run(resume_text=text)
    time.sleep(3)
    return response

for text in resume_text:
    j = generate_fields_from_resume(text)
    json_data.append(j)
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[87], line 36
#      33     return response
#      35 for text in resume_text:
# ---> 36     j = generate_fields_from_resume(text)
#      37     json_data.append(j)
#
# Cell In[87], line 31, in generate_fields_from_resume(resume_text)
#       3     prompt_template = PromptTemplate.from_template(
#       4         """Extract the following fields from the resume text
#       5 1. first_name
#    (...)
#      27 """
#      28     )
#      30     chain = LLMChain(llm=llm, prompt=prompt_template)
# ---> 31     response = chain.run(resume_text=text)
#      32     time.sleep(3)
#      33     return response
#
# ...

# %%
print(json_data[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 print(json_data[1])
#
# IndexError: list index out of range

# %%
for i in json_data:
    print(type(i))
# print(type(json_data[0]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
data_dict = json.loads(json_data[6])

# %%
print(data_dict)
# Out:
# {'first_name': 'NISHANA', 'last_name': 'M', 'emails': ['nishananizar12@gmail.com'], 'phones': ['9600397647'], 'skills': ['UI/UX Design', 'UX Researc', 'Usability Testin', 'Wireframin', 'Graphic Desig', 'Layout Desig', 'App Desig', 'Email marketin', 'Visual Desig', 'Video creatio', 'Digital Marketing', 'Prototyping', 'Ads Management'], 'highest_degree_details': 'Diploma in Hotel Management (Hospitality) 2013 Coimbatore Amirta International Institute', 'pg_degree': None, 'ug_degree': 'Diploma in Hotel Management', 'ug_graduation_year': 2013, 'first_working_date': '04/2016', 'state': 'India', 'city': 'Banglore', 'company_history': [{'company': 'Xogar Games', 'position': 'UI/UX Designer', 'start_date': '11/2023', 'end_date': 'Present'}, {'company': 'ORB 25 Tools', 'position': 'Digital Marketer & UI/UX Designer', 'start_date': '03/2022', 'end_date': '02/2023'}, {'company': 'Jaikrishna maruti pvt ltd.,', 'position': 'Customer care Executive', 'start_date': '04/2016', 'end_date': '11/2021'}
# ...

# %%
len(json_data)
# Out:
# 10

# %%
print(json_data[2].replace('\n', ' '))
# Out:
# ```json {   "first_name": "Priyadharshini",   "last_name": "SomaSundaram",   "emails": [     "sdpriyadharshini2024@gmail.com"   ],   "phones": [     "+91 8056459451"   ],   "skills": [     "Java",     "J2EE",     "SpringBoot",     "SOAP",     "REST API",     "Spring Batch Framework",     "Struts",     "Android",     "WODM",     "Eclipse",     "Weblogic",     "Ninjago",     "Jenkins",     "DBeaver",     "JSP",     "Servlets",     "PL/SQL",     "AJAX",     "JSON",     "XML",     "Android SDK",     "ADT",     "IBM-WODM",     "AVD",     "GIT",     "JMeter",     "SOAP UI",     "Kafka",     "Mockito",     "PowerMockito",     "Redis API",     "DB2",     "Go Lang",     "Guardium Insights",     "Mule Server",     "Tomcat",     "Oracle",     "Splunk",     "BitBucket",     "Postman",     "HPSA",     "Introscope",     "TOAD",     "Visio"   ],   "highest_degree_details": "BE, Computer Science And Engineering, Sri Krishna College of Engineering and Technology, Coimbatore, 80%, March,2009",   "pg_d
# ...

# %%
print(type(json.loads(json_data[2].replace('\n', ' '))))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[209], line 1
# ----> 1 print(type(json.loads(json_data[2].replace('\n', ' '))))
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
# ...

# %%
data_dict = json.loads(json_data[2])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 data_dict = json.loads(json_data[2])
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
# ...

# %%
json_data.remove(json_data[2])

# %%
len(json_data)
# Out:
# 9

# %%
df.drop(2)
# Out:
#                                  File_Name  Filesize_in_mb File_Type  \
# 0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 3         web-developer-resume-example.pdf            0.04       pdf
# 4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf
# 6       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54       pdf
# 7                        radhakrishnan.pdf            0.06       pdf
# 8                       Resume_AI Team.pdf            0.31       pdf
# 9       Naukri_RadhakrishnanM[3y_0m] 1.pdf            0.06       pdf
#
#                                            File_text
# 0  SANJAY KUMAR S\nPhone: +91 7094583155 | Email:...
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index                                File_Name  Filesize_in_mb File_Type  \
# 0      0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 2      2       Naukri_PriyadharshiniS[14y_0m].pdf            0.22       pdf
# 3      3         web-developer-resume-example.pdf            0.04       pdf
# 4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
#
#                                            File_text
# 0  SANJAY KUMAR S\nPhone: +91 7094583155 | Email:...
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 2  PRIYADHARSHINI S\nMail to: sdpriyadharshini202...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...

# %%
json_data
# Out:
# ['{"first_name": "SANJAY", "last_name": "KUMAR", "emails": ["sanjaykumarcsk2002@gmail.com"], "phones": ["+91 7094583155"], "skills": ["Java", "Python", "C", "HTML", "CSS", "MySQL", "Flask", "Bootstrap", "Eclipse", "Visual Studio Code", "Talend Open Studio", "Jupyter Notebook", "Communication", "Leadership", "Problem Solving", "Project management", "Attention to Detail"], "highest_degree_details": "B.E (CSE) 9.1(CGPA) 2019-2023", "pg_degree": null, "ug_degree": "B.E", "ug_graduation_year": 2023, "first_working_date": null, "state": null, "city": null, "company_history": [], "marital_status": null, "gender": null, "skill_bucket": ["Programming Languages", "Frontend", "Database", "Frameworks", "Tools and IDEs\'", "Soft Skills"], "domain_experience": ["Data Integration", "ETL", "Data Science"]}\n',
# ...

# %%
for i in json_data:
    if isinstance(i, dict):
        continue
    else:
        ind = json_data.index(i)
        json_data[ind] = json.loads(i.replace('\n', ' '))

# %%
for i in json_data:
    print(type(i))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
json_data
# Out:
# [{'first_name': 'RADHA',
#   'last_name': 'KRISHNAN',
#   'emails': ['rkkrish451@gmail.com'],
#   'phones': ['9489574510'],
#   'skills': ['Design Strategy',
#    'Problem Solving',
#    'Usability Testing',
#    'User Flow',
#    'Wireframes',
#    'Prototypes',
#    'User Research',
#    'Design Thinking',
#    'User-Centered Design',
#    'Adobe XD',
#    'Figma',
#    'Flimora',
#    'Photoshop'],
#   'highest_degree_details': 'Bachelor of Technology in Information Technology',
#   'pg_degree': None,
#   'ug_degree': 'Bachelor of Technology',
#   'ug_graduation_year': 2021,
#   'first_working_date': '2021',
#   'state': 'Tamil Nadu',
#   'city': 'Coimbatore',
#   'company_history': [{'company': 'Highonswift',
#     'from': '2021',
#     'to': '2024',
#     'designation': 'UI/UX DESIGNER'}],
#   'marital_status': None,
#   'gender': None,
#   'skill_bucket': [],
#   'domain_experience': []},
#  {'first_name': 'Vijaykumar',
#   'last_name': 'SD',
# ...

# %%
df['JSON_data'] = json_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[233], line 1
# ----> 1 df['JSON_data'] = json_data
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
# ...

# %%
len(df)
# Out:
# 10

# %%
df.head()
# Out:
#    index                                File_Name  Filesize_in_mb File_Type  \
# 0      0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 2      2       Naukri_PriyadharshiniS[14y_0m].pdf            0.22       pdf
# 3      3         web-developer-resume-example.pdf            0.04       pdf
# 4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
#
#                                            File_text
# 0  SANJAY KUMAR S\nPhone: +91 7094583155 | Email:...
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 2  PRIYADHARSHINI S\nMail to: sdpriyadharshini202...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...

# %%
df.drop(2,inplace = "True")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 df.drop(2,inplace = "True")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.drop(2,inplace
# Out:
#    index                                File_Name  Filesize_in_mb File_Type  \
# 0      0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 2      2       Naukri_PriyadharshiniS[14y_0m].pdf            0.22       pdf
# 3      3         web-developer-resume-example.pdf            0.04       pdf
# 4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
#
#                                            File_text
# 0  SANJAY KUMAR S\nPhone: +91 7094583155 | Email:...
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 2  PRIYADHARSHINI S\nMail to: sdpriyadharshini202...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...

# %%
df.drop(2,axis='rows',inplace=True)

# %%
df.reset_index()
# Out:
#    level_0  index                                File_Name  Filesize_in_mb  \
# 0        0      0                SANJAY KUMAR S Resume.pdf            0.28
# 1        1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81
# 2        3      3         web-developer-resume-example.pdf            0.04
# 3        4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23
# 4        5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82
# 5        6      6       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54
# 6        7      7                        radhakrishnan.pdf            0.06
# 7        8      8                       Resume_AI Team.pdf            0.31
# 8        9      9       Naukri_RadhakrishnanM[3y_0m] 1.pdf            0.06
#
#   File_Type                                          File_text
# 0       pdf  SANJAY KUMAR S\nPhone: +91 7094583155 | Email:...
# 1       pdf  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# ...

# %%
df.head()
# Out:
#    index                                File_Name  Filesize_in_mb File_Type  \
# 0      0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 3      3         web-developer-resume-example.pdf            0.04       pdf
# 4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf
#
#                                            File_text
# 0  SANJAY KUMAR S\nPhone: +91 7094583155 | Email:...
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...
# 5  Contact Details\nKarthickraja E M\n766-722-326...

# %%
df['JSON_data'] = json_data

# %%
json_data[8]
# Out:
# {'first_name': 'RADHA',
#  'last_name': 'KRISHNAN',
#  'emails': ['rkkrish451@gmail.com'],
#  'phones': ['9489574510'],
#  'skills': ['Design Strategy',
#   'Problem Solving',
#   'Usability Testing',
#   'User Flow',
#   'Wireframes',
#   'Prototypes',
#   'User Research',
#   'Design Thinking',
#   'User-Centered Design',
#   'Adobe XD',
#   'Figma',
#   'Flimora',
#   'Photoshop'],
#  'highest_degree_details': 'Bachelor of Technology in Information Technology',
#  'pg_degree': None,
#  'ug_degree': 'Bachelor of Technology',
#  'ug_graduation_year': 2021,
#  'first_working_date': '2021',
#  'state': 'Tamil Nadu',
#  'city': 'Coimbatore',
#  'company_history': [{'company': 'Highonswift',
#    'from': '2021',
#    'to': '2024',
#    'designation': 'UI/UX DESIGNER'}],
#  'marital_status': None,
#  'gender': None,
#  'skill_bucket': [],
#  'domain_experience': []}

# %%
df.head()
# Out:
#    index                                File_Name  Filesize_in_mb File_Type  \
# 0      0                SANJAY KUMAR S Resume.pdf            0.28       pdf
# 1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 3      3         web-developer-resume-example.pdf            0.04       pdf
# 4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf
#
#                                            File_text  \
# 0  SANJAY KUMAR S\nPhone: +91 7094583155 | Email:...
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...
# 5  Contact Details\nKarthickraja E M\n766-722-326...
#
#                                            JSON_data
# 0  {'first_name': 'RADHA', 'last_name': 'KRISHNAN...
# 1  {'first_name': 'Vijaykumar', 'last_name': 'SD'...
# ...

# %%
df.drop(0,axis="rows",inplace=True)

# %%
df.reset_index()
# Out:
#    level_0  index                                File_Name  Filesize_in_mb  \
# 0        1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81
# 1        3      3         web-developer-resume-example.pdf            0.04
# 2        4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23
# 3        5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82
# 4        6      6       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54
# 5        7      7                        radhakrishnan.pdf            0.06
# 6        8      8                       Resume_AI Team.pdf            0.31
# 7        9      9       Naukri_RadhakrishnanM[3y_0m] 1.pdf            0.06
#
#   File_Type                                          File_text  \
# 0       pdf  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 1       pdf  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 2       pdf  Kiruba J\nUI & UX Designer and Product designe...
# ...

# %%
df.head()
# Out:
#    index                                File_Name  Filesize_in_mb File_Type  \
# 1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 3      3         web-developer-resume-example.pdf            0.04       pdf
# 4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf
# 6      6       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54       pdf
#
#                                            File_text  \
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...
# 5  Contact Details\nKarthickraja E M\n766-722-326...
# 6  9600397647\nNISHANA.M\nnishananizar12@gmail.co...
#
#                                            JSON_data
# 1  {'first_name': 'Vijaykumar', 'last_name': 'SD'...
# 3  {'first_name': 'JACKSON', 'last_name': 'MACART...
# ...

# %%
df.head(10)
# Out:
#    index                                File_Name  Filesize_in_mb File_Type  \
# 1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81       pdf
# 3      3         web-developer-resume-example.pdf            0.04       pdf
# 4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23       pdf
# 5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82       pdf
# 6      6       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54       pdf
# 7      7                        radhakrishnan.pdf            0.06       pdf
# 8      8                       Resume_AI Team.pdf            0.31       pdf
# 9      9       Naukri_RadhakrishnanM[3y_0m] 1.pdf            0.06       pdf
#
#                                            File_text  \
# 1  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 3  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 4  Kiruba J\nUI & UX Designer and Product designe...
# 5  Contact Details\nKarthickraja E M\n766-722-326...
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    level_0  index                                File_Name  Filesize_in_mb  \
# 0        1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81
# 1        3      3         web-developer-resume-example.pdf            0.04
# 2        4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23
# 3        5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82
# 4        6      6       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54
#
#   File_Type                                          File_text  \
# 0       pdf  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 1       pdf  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 2       pdf  Kiruba J\nUI & UX Designer and Product designe...
# 3       pdf  Contact Details\nKarthickraja E M\n766-722-326...
# 4       pdf  9600397647\nNISHANA.M\nnishananizar12@gmail.co...
#
#                                            JSON_data
# 0  {'first_name': 'Vijaykumar', 'last_name': 'SD'...
# ...

# %%
df.head(9)
# Out:
#    level_0  index                                File_Name  Filesize_in_mb  \
# 0        1      1  Naukri_VijayKumarSDBEMBACSM[12y_0m].pdf            0.81
# 1        3      3         web-developer-resume-example.pdf            0.04
# 2        4      4              Naukri_KirubaJ[4y_0m] 1.pdf            1.23
# 3        5      5       Naukri_KarthickrajaEM[3y_0m] 1.pdf            0.82
# 4        6      6       Naukri_NishanaPradeep[2y_0m] 1.pdf            0.54
# 5        7      7                        radhakrishnan.pdf            0.06
# 6        8      8                       Resume_AI Team.pdf            0.31
# 7        9      9       Naukri_RadhakrishnanM[3y_0m] 1.pdf            0.06
#
#   File_Type                                          File_text  \
# 0       pdf  Vijaykumar SD\nContact: +91 9566859696\nE-Mail...
# 1       pdf  JACKSON CAREER OBJECTIVE\nSoftware engineer wi...
# 2       pdf  Kiruba J\nUI & UX Designer and Product designe...
# ...

# %%
# !pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 11.6 MB/s eta 0:00:0031m12.3 MB/s eta 0:00:01
# ...

# %%
df.to_parquet('/home/sanjay_kumar/Downloads/resume.parquet', engine='fastparquet')
